# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns

# %%
df=pd.read_csv('netflix.csv')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Shape of dataset 
df.shape
# Out:
# (8807, 12)

# %%
# shows 8807 rows and 12 columns in the dataset

# %%
# Top 5 rows
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#Last 5 rows
df.tail(5)
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# Datatypes of attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# Finding is null values
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# Finding count of null values
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.fillna('NaN')
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# droppping description coulmn as not needed
df.drop('description',axis=1,inplace=True)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
# Handling missing values of different columns

# %%
# missing director values filled with 'Not available'
df['director']=df['director'].fillna('Not Available')

# missing cast values filled with 'Not available'
df['cast']=df['cast'].fillna('Not Available')

# country column filled with most frequent value
frequent_country=df['country'].mode()[0]
df['country']=df['country'].fillna(frequent_country)

# date added filled with most frequent value
frequent_date=df['date_added'].mode()[0]
df['date_added']=df['date_added'].fillna(frequent_date)

# rating column filled with most frequent value
frequent_rating=df['rating'].mode()[0]
df['rating']=df['rating'].fillna(frequent_rating)

# duration filled with most frequent value
frequent_duration=df['duration'].mode()[0]
df['duration']=df['duration'].fillna(frequent_duration)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR',
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
# # converting release year to date time format
# df["release_year"] = pd.to_datetime(df["release_year"], format="%Y")

# %%
# To check if nested columns in country column
nested_list_country = any(isinstance(sub, list) for sub in df['country'])
nested_list_country
# Out:
# False

# %%
# To check if nested columns in director column
nested_list_country = any(isinstance(sub, list) for sub in df['director'])
nested_list_country
# Out:
# False

# %%
#To check if nested columns in director column
nested_list_country = any(isinstance(sub, list) for sub in df['cast'])
nested_list_country
# Out:
# False

# %%
# Univariate analysis

# %%
#No of TV Shows and Movies
plt.figure(figsize=(12,8))
sns.countplot(data=df,x='type',order=df['type'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insight: Netflix has more no of movies in comparison to TV shows

# %%
# Variation of content released with year
sns.histplot(df['release_year'],kde=True,bins=30)
plt.show()

# %% [markdown]
# Insight : Content released increased almost exponentially in last 20-30 years

# %%
# Top 10 directors 
df1=df[df['director']!= 'Not Available']
top_10_directors=df1['director'].value_counts().head(10)
sns.barplot(x=top_10_directors.index, y=top_10_directors.values)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insight : Rajiv Chilaka is topmost director

# %%
# Top 10 actors
df["lead_actor"] = df["cast"].str.split(",").str[0]
df1=df[df['lead_actor']!= 'Not Available']
top_10_directors=df1['lead_actor'].value_counts().head(10)
sns.barplot(x=top_10_directors.index, y=top_10_directors.values)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insight : Shah rukh Khan is topmost actor

# %%
# # Outlier check for Duration of Movie/TV show
# df['movie_mins']=np.where(df['type']=='Movie', df['duration'].str[:-4], None)
# df['movie_mins'] = df['movie_mins'].astype('float')


# df['tv_seasons']=np.where(df['type']=='TV Show', df['duration'].str[:-7]
#                           .apply(lambda x: x.strip()),None)
# df['tv_seasons']=df['tv_seasons'].astype('float')

# %%
## Correlation between Genre and Country

# %%
country_df=df.copy()
country_df['listed_in'] = country_df['listed_in'].astype('str').apply(
    lambda x: x.split(', '))

# Explode the rows with multiple categories to different rows
country_genre_df = country_df.explode('listed_in').drop_duplicates()

# %%
#Top 20 countries by count of titles
top_20 = country_df.country.value_counts().reset_index()
top_20 = top_20.loc[:20,'index'].to_list()
#top_20.remove('nan')
top_20_df = country_genre_df.loc[country_genre_df['country'].isin(top_20)]

# %%
def custom_agg(x):
    return x.nunique()

data = pd.pivot_table(top_20_df, index = top_20_df['listed_in'],
                      columns = top_20_df['country'],
                      values = 'show_id', aggfunc=custom_agg)

# %%
plt.figure(figsize=(12,8))
#ax=sns.heatmap(data,annot=True,fmt=".0f")
ax = sns.heatmap(data, annot=True, fmt=".0f",
                  norm=matplotlib.colors.LogNorm(vmin=data.min().min(),
                                                 vmax=data.max().max()))
ax.set(xlabel="Countries", ylabel="Categories", title='Countries v/s Genres');

# %%
Insight: Action & Adventure, Children and Family movies,Comedies are popular genre
# Out:
#   File "C:\Users\KIRTY\AppData\Local\Temp/ipykernel_15928/1946937607.py", line 1
#     Insight: Action & Adventure, Children and Family movies,Comedies are popular genre
#                                ^
# SyntaxError: invalid syntax

# %%
# Content in diff country
plt.figure(figsize=(12,8))
sns.countplot(data=df,x='rating',hue='type',order=df['rating'].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Insight: TV-MA,TV-14 is the most frequent rating used for Movie and TV show

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(x='rating', y='release_year', data=df, palette='Set1')
plt.title('Distribution of Release Years by Rating')
plt.xlabel('Rating')
plt.ylabel('Release Year')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insight: Median release year for most ratings are between 2005 to 2020

# %% [markdown]
# # Business Insight

# %% [markdown]
# 1. Release year
#
#    a. In 2018 highest number of movies and TV shows are added
#    b. After 2015 there is increase in no. of movies added
#
#
#
# 2. Content across countries
#
#     a. USA,India,UK , Canada has highest number of content
#     b. US and UK has good mix of all genre
#
#
# 3. Genre
#
#    Most popular genres: Action & Adventure, Children & Family Movies, Comedies,
#    Dramas, International Movies & TV Shows, TV Dramas, Thrillers
#
#
#
# 4. Rating
#
#    TV-MA and TV 14 are the highest rating used for Movies as well as TV shows

# %% [markdown]
# # Recommendations

# %% [markdown]
# 1. To cover the mass population Netflix should produce more Family and children oriented movies.
#
# 2. The release year in countries can be around long weekends or Festive seasons to have more viewership.
#
# 3. The content across all the countries should have a good mix like as in USA and UK.
#
# 4. The content can be made to target older population as well.
#
# 5. Shows and Movies can be added from different languages in countries like India to increase customers
#
# 6. As customers prefering short duration content more , that can be promoted.
#
# 7. As business doing good in USA , UK , India , China , next big populated countries can be targeted.
